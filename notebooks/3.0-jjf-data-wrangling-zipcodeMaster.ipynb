# %% [markdown]
# ## Data Wrangling - Zipcode Aggregation of All Datas
# from FRED public data and Zillow public data

# %%
#Import pandas, matplotlib.pyplot, and seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
#change directory to get data
path= '/Users/josephfrasca/Coding_Stuff/Springboard/Capstone_2/data/interim'
os.chdir(path)

# %%
os.listdir()
# Out:
# ['.gitkeep',
#  '.ipynb_checkpoints',
#  'ACS_rentsPrices_2011_2018.csv',
#  'ACS_zillow_2011_2018.csv',
#  'Annual_fredData_2011_2019',
#  'df3_1956',
#  'df_homePrices_2011_2018',
#  'df_homePrices_2011_2020',
#  'df_homePrices_2011_2020.csv',
#  'df_rentPrices_2014_2020',
#  'df_rentPrices_2014_2020.csv',
#  'VacancyRate_Zipcode_2011_2018',
#  'VacancyRate_Zipcode_2011_2018.csv',
#  'zillow_rentPrices_2014_2020.csv']

# %%
#load rental data
df_fred = pd.read_csv('Annual_fredData_2011_2019')
df_homes = pd.read_csv("df_homePrices_2011_2020.csv", converters={'RegionName': lambda x: str(x)})
df_rents = pd.read_csv('ACS_rentsPrices_2011_2018.csv', dtype={'RegionID': object, 'RegionName': object})
df_vacancy = pd.read_csv('VacancyRate_Zipcode_2011_2018.csv', dtype={'Zipcode': object})

#secondary rental data
ACS_Rents2011_18 = pd.read_csv('ACS_zillow_2011_2018.csv', dtype={'RegionID': object, 'RegionName': object})
zillow_Rents2014_20 = pd.read_csv('zillow_rentPrices_2014_2020.csv', dtype={'RegionID': object, 'RegionName': object})

# %% [markdown]
# ### Data Definition

# %%
df_vacancy
# Out:
#        Zipcode  Vacancy_Rate%  MOE-VacancyRate%  Year
# 0        02333       3.024027          2.199925  2011
# 1        02338       3.116343          2.948791  2011
# 2        02339       4.464646          2.066438  2011
# 3        02341       3.586322          2.340722  2011
# 4        02343       3.732901          2.926524  2011
# ...        ...            ...               ...   ...
# 264955   98279      51.219512         10.993457  2018
# 264956   98280      51.329243         12.777549  2018
# 264957   98311       6.540162          1.960476  2018
# 264958   98326      28.537736         14.679524  2018
# 264959   98332       7.340077          2.726737  2018
#
# [264960 rows x 4 columns]

# %%
df_homes
# Out:
#         SizeRank RegionName State       City  \
# 0              0      10025    NY   New York
# 1              1      60657    IL    Chicago
# 2              2      10023    NY   New York
# 3              3      77494    TX       Katy
# 4              4      60614    IL    Chicago
# ...          ...        ...   ...        ...
# 303665     34430      43523    OH    Malinta
# 303666     34430       7703    NJ  Eatontown
# 303667     34430      47865    IN   Carlisle
# 303668     35187        822    LA  Choudrant
# 303669     35187        820    LA  Choudrant
#
#                                    Metro       CountyName  HomePrice  Year
# 0            New York-Newark-Jersey City  New York County  784477.42  2011
# 1               Chicago-Naperville-Elgin      Cook County  400695.83  2011
# 2            New York-Newark-Jersey City  New York County  821072.58  2011
# 3       Houston-The Woodlands-Sugar Land    Harris County  265425.17  2011
# 4               Chicago-Naperville-Elgin      Cook County  507804.42  2011
# ...                                  ...              ...        ...   ...
# 303665                               NaN     Henry County   84331.11  2020
# 303666       New York-Newark-Jersey City  Monmouth County  579932.56  2020
# 303667                       Terre Haute  Sullivan County   42896.56  2020
# 303668                            Ruston   Lincoln Parish  195888.67  2020
# 303669                            Ruston   Lincoln Parish  242009.56  2020
#
# [303670 rows x 8 columns]

# %% [markdown]
# ### Data Cleaning 1 - HomePrices

# %%
#add leading zeros to zipcode in home dataframe
df_homes['RegionName'] = df_homes['RegionName'].apply(lambda x: '{0:0>5}'.format(x))

# %%
df_homes
# Out:
#         SizeRank RegionName State       City  \
# 0              0      10025    NY   New York
# 1              1      60657    IL    Chicago
# 2              2      10023    NY   New York
# 3              3      77494    TX       Katy
# 4              4      60614    IL    Chicago
# ...          ...        ...   ...        ...
# 303665     34430      43523    OH    Malinta
# 303666     34430      07703    NJ  Eatontown
# 303667     34430      47865    IN   Carlisle
# 303668     35187      00822    LA  Choudrant
# 303669     35187      00820    LA  Choudrant
#
#                                    Metro       CountyName  HomePrice  Year
# 0            New York-Newark-Jersey City  New York County  784477.42  2011
# 1               Chicago-Naperville-Elgin      Cook County  400695.83  2011
# 2            New York-Newark-Jersey City  New York County  821072.58  2011
# 3       Houston-The Woodlands-Sugar Land    Harris County  265425.17  2011
# 4               Chicago-Naperville-Elgin      Cook County  507804.42  2011
# ...                                  ...              ...        ...   ...
# 303665                               NaN     Henry County   84331.11  2020
# 303666       New York-Newark-Jersey City  Monmouth County  579932.56  2020
# 303667                       Terre Haute  Sullivan County   42896.56  2020
# 303668                            Ruston   Lincoln Parish  195888.67  2020
# 303669                            Ruston   Lincoln Parish  242009.56  2020
#
# [303670 rows x 8 columns]

# %%
#rename Zipcode column
df_homes = df_homes.rename(columns = {'RegionName':'Zipcode'})
#check for NaNs
df_homes.isna().sum()
# Out:
# SizeRank          0
# Zipcode           0
# State             0
# City              0
# Metro         71180
# CountyName        0
# HomePrice     11066
# Year              0
# dtype: int64

# %%
#subset df_homes data for year 2011-2018 (for merging with FRED data)
df_homes_2011_2018 = df_homes.loc[df_homes['Year'] < 2019]

# %%
#subset df_homes data for year 2014-2020 (for merging with rent data)
#df_homes_2014_2020 = df_homes.loc[df_homes['Year'] > 2013]

# %%
#df_homes_2014_2020[df_homes_2014_2020.Year == 2014]
# Out:
#         SizeRank Zipcode State       City                             Metro  \
# 91101          0   10025    NY   New York       New York-Newark-Jersey City
# 91102          1   60657    IL    Chicago          Chicago-Naperville-Elgin
# 91103          2   10023    NY   New York       New York-Newark-Jersey City
# 91104          3   77494    TX       Katy  Houston-The Woodlands-Sugar Land
# 91105          4   60614    IL    Chicago          Chicago-Naperville-Elgin
# ...          ...     ...   ...        ...                               ...
# 121463     34430   43523    OH    Malinta                               NaN
# 121464     34430   07703    NJ  Eatontown       New York-Newark-Jersey City
# 121465     34430   47865    IN   Carlisle                       Terre Haute
# 121466     35187   00822    LA  Choudrant                            Ruston
# 121467     35187   00820    LA  Choudrant                            Ruston
#
#              CountyName   HomePrice  Year
# 91101   New York County   968761.75  2014
# 91102       Cook County   450755.75  2014
# 91103   New York County  1024543.17  2014
# 91104     Harris County   322032.00  2014
# 91105       Cook County   580250.92  2014
# ...                 ...         ...   ...
# 121463     Henry County    67959.33  2014
# 121464  Monmouth County         NaN  2014
# 121465  Sullivan County         NaN  2014
# 121466   Lincoln Parish   140783.33  2014
# 121467   Lincoln Parish   231314.67  2014
#
# [30367 rows x 8 columns]

# %%
df_homes_2011_2018
# Out:
#         SizeRank Zipcode State       City                             Metro  \
# 0              0   10025    NY   New York       New York-Newark-Jersey City
# 1              1   60657    IL    Chicago          Chicago-Naperville-Elgin
# 2              2   10023    NY   New York       New York-Newark-Jersey City
# 3              3   77494    TX       Katy  Houston-The Woodlands-Sugar Land
# 4              4   60614    IL    Chicago          Chicago-Naperville-Elgin
# ...          ...     ...   ...        ...                               ...
# 242931     34430   43523    OH    Malinta                               NaN
# 242932     34430   07703    NJ  Eatontown       New York-Newark-Jersey City
# 242933     34430   47865    IN   Carlisle                       Terre Haute
# 242934     35187   00822    LA  Choudrant                            Ruston
# 242935     35187   00820    LA  Choudrant                            Ruston
#
#              CountyName  HomePrice  Year
# 0       New York County  784477.42  2011
# 1           Cook County  400695.83  2011
# 2       New York County  821072.58  2011
# 3         Harris County  265425.17  2011
# 4           Cook County  507804.42  2011
# ...                 ...        ...   ...
# 242931     Henry County   81699.58  2018
# 242932  Monmouth County  543333.30  2018
# 242933  Sullivan County   40215.62  2018
# 242934   Lincoln Parish  178884.17  2018
# 242935   Lincoln Parish  224375.33  2018
#
# [242936 rows x 8 columns]

# %%
#check %NaNs in home_price data
df_homes_2011_2018.isna().sum()/len(df_homes_2011_2018)*100
# Out:
# SizeRank       0.000000
# Zipcode        0.000000
# State          0.000000
# City           0.000000
# Metro         23.439918
# CountyName     0.000000
# HomePrice      4.555109
# Year           0.000000
# dtype: float64

# %%
#replace home price NaNs with first:
    #diff = (price of year you have) - (mean of a year you have) 
    #then replace NaN with 'diff' + (mean of NaN year)

# %% [markdown]
# ### Data Cleaning 2 - RentPrices

# %%
df_rents
# Out:
#        Zipcode  RentPrice  Year
# 0        02333   1368.536  2011
# 1        02338   1311.076  2011
# 2        02339   1484.626  2011
# 3        02341   1266.816  2011
# 4        02343   1524.006  2011
# ...        ...        ...   ...
# 264955   98279   1059.870  2018
# 264956   98280    993.850  2018
# 264957   98311   1533.500  2018
# 264958   98326    778.990  2018
# 264959   98332   1840.860  2018
#
# [264960 rows x 3 columns]

# %%
#add leading zeros to zipcode in rent dataframe
df_rents['RegionName'] = df_rents['RegionName'].apply(lambda x: '{0:0>5}'.format(x))

# %%
df_rents
# Out:
#        RegionName  RentPrice  Year
# 0           02333   1368.536  2011
# 1           02338   1311.076  2011
# 2           02339   1484.626  2011
# 3           02341   1266.816  2011
# 4           02343   1524.006  2011
# ...           ...        ...   ...
# 264955      98279   1059.870  2018
# 264956      98280    993.850  2018
# 264957      98311   1533.500  2018
# 264958      98326    778.990  2018
# 264959      98332   1840.860  2018
#
# [264960 rows x 3 columns]

# %%
#rename Zipcode column
df_rents = df_rents.rename(columns={'RegionName': 'Zipcode'})

# %%
#check for % NaNs
df_rents.isna().sum()/len(df_rents)*100
# Out:
# Zipcode      0.00000
# RentPrice    7.51321
# Year         0.00000
# dtype: float64

# %%
#replace home price NaNs with first:
    #diff = (price of year you have) - (mean of a year you have) 
    #then replace NaN with 'diff' + (mean of NaN year)

# %% [markdown]
# ### Data Cleaning 3 - FRED Economic Data

# %%
df_fred.head()
# Out:
#          DATE  int_rate  med_hIncome  uspop_growth  unemplt_rate  \
# 0  2011-01-01  0.750000      57021.0      0.720018      8.933333
# 1  2012-01-01  0.750000      56912.0      0.727269      8.075000
# 2  2013-01-01  0.750000      58904.0      0.686773      7.358333
# 3  2014-01-01  0.750000      58001.0      0.727518      6.158333
# 4  2015-01-01  0.770833      60987.0      0.730641      5.275000
#
#    newHouse_starts  resConstruct_spending
# 0       611.916667          255208.583333
# 1       783.750000          278995.583333
# 2       928.166667          335207.333333
# 3      1000.250000          382868.333333
# 4      1106.750000          438118.333333

# %%
#change year to match df_vacancy format
df_fred.DATE = df_fred.DATE.str.replace('-01-01','')

# %%
#change DATE column name to Year
df_fred = df_fred.rename(columns = {'DATE':'Year'})

# %%
#subset FRED data to 2011-2018 to prep for merge
df_fred_2011_2018 = df_fred.iloc[0:8]
df_fred_2011_2018 = df_fred_2011_2018.astype({'Year': 'int32'})

# %%
df_fred_2011_2018.dtypes
# Out:
# Year                       int32
# int_rate                 float64
# med_hIncome              float64
# uspop_growth             float64
# unemplt_rate             float64
# newHouse_starts          float64
# resConstruct_spending    float64
# dtype: object

# %%
df_vacancy.dtypes
# Out:
# Zipcode              object
# Vacancy_Rate%       float64
# MOE-VacancyRate%    float64
# Year                  int64
# dtype: object

# %%
df_fred_2011_2018
# Out:
#    Year  int_rate  med_hIncome  uspop_growth  unemplt_rate  newHouse_starts  \
# 0  2011  0.750000      57021.0      0.720018      8.933333       611.916667
# 1  2012  0.750000      56912.0      0.727269      8.075000       783.750000
# 2  2013  0.750000      58904.0      0.686773      7.358333       928.166667
# 3  2014  0.750000      58001.0      0.727518      6.158333      1000.250000
# 4  2015  0.770833      60987.0      0.730641      5.275000      1106.750000
# 5  2016  1.020833      62898.0      0.716669      4.875000      1176.583333
# 6  2017  1.625000      63761.0      0.631008      4.341667      1207.416667
# 7  2018  2.458333      64324.0      0.522337      3.891667      1248.250000
#
#    resConstruct_spending
# 0          255208.583333
# 1          278995.583333
# 2          335207.333333
# 3          382868.333333
# 4          438118.333333
# 5          485822.500000
# 6          546020.166667
# 7          564448.750000

# %% [markdown]
# ### Data Joining

# %%
#merge rent prices and home prices (2011-2018)
df_rent_merged_homes = pd.merge(df_rents, df_homes_2011_2018,how='left', on=['Year', 'Zipcode'])
df_rent_merged_homes
# Out:
#        Zipcode  RentPrice  Year  SizeRank State              City  \
# 0        02333   1368.536  2011    8782.0    MA  East Bridgewater
# 1        02338   1311.076  2011   11179.0    MA           Halifax
# 2        02339   1484.626  2011    8621.0    MA           Hanover
# 3        02341   1266.816  2011   10079.0    MA            Hanson
# 4        02343   1524.006  2011    9640.0    MA          Holbrook
# ...        ...        ...   ...       ...   ...               ...
# 264955   98279   1059.870  2018   23400.0    WA              Olga
# 264956   98280    993.850  2018   25265.0    WA         Eastsound
# 264957   98311   1533.500  2018    4981.0    WA         Bremerton
# 264958   98326    778.990  2018   26185.0    WA       Clallam Bay
# 264959   98332   1840.860  2018    6759.0    WA        Gig Harbor
#
#                           Metro       CountyName  HomePrice
# 0       Boston-Cambridge-Newton  Plymouth County        NaN
# 1       Boston-Cambridge-Newton  Plymouth County  274920.17
# 2       Boston-Cambridge-Newton  Plymouth County  415097.50
# 3       Boston-Cambridge-Newton  Plymouth County        NaN
# 4       Boston-Cambridge-Newton   Norfolk County  247510.42
# ...                         ...              ...        ...
# 264955                      NaN  San Juan County  552805.42
# 264956                      NaN  San Juan County  678499.00
# 264957     Bremerton-Silverdale    Kitsap County  314320.83
# 264958             Port Angeles   Clallam County  150193.17
# 264959  Seattle-Tacoma-Bellevue    Pierce County  535136.75
#
# [264960 rows x 9 columns]

# %%
#merge df_vacancy + FRED data 2011-2018
df_vacany_merged_fred = pd.merge(df_vacancy, df_fred_2011_2018, how='left', on='Year')
df_vacany_merged_fred
# Out:
#        Zipcode  Vacancy_Rate%  MOE-VacancyRate%  Year  int_rate  med_hIncome  \
# 0        02333       3.024027          2.199925  2011  0.750000      57021.0
# 1        02338       3.116343          2.948791  2011  0.750000      57021.0
# 2        02339       4.464646          2.066438  2011  0.750000      57021.0
# 3        02341       3.586322          2.340722  2011  0.750000      57021.0
# 4        02343       3.732901          2.926524  2011  0.750000      57021.0
# ...        ...            ...               ...   ...       ...          ...
# 264955   98279      51.219512         10.993457  2018  2.458333      64324.0
# 264956   98280      51.329243         12.777549  2018  2.458333      64324.0
# 264957   98311       6.540162          1.960476  2018  2.458333      64324.0
# 264958   98326      28.537736         14.679524  2018  2.458333      64324.0
# 264959   98332       7.340077          2.726737  2018  2.458333      64324.0
#
#         uspop_growth  unemplt_rate  newHouse_starts  resConstruct_spending
# 0           0.720018      8.933333       611.916667          255208.583333
# 1           0.720018      8.933333       611.916667          255208.583333
# 2           0.720018      8.933333       611.916667          255208.583333
# 3           0.720018      8.933333       611.916667          255208.583333
# 4           0.720018      8.933333       611.916667          255208.583333
# ...              ...           ...              ...                    ...
# 264955      0.522337      3.891667      1248.250000          564448.750000
# 264956      0.522337      3.891667      1248.250000          564448.750000
# 264957      0.522337      3.891667      1248.250000          564448.750000
# 264958      0.522337      3.891667      1248.250000          564448.750000
# 264959      0.522337      3.891667      1248.250000          564448.750000
#
# [264960 rows x 10 columns]

# %%
#merge all four datasets together
df_complete = pd.merge(df_rent_merged_homes, df_vacany_merged_fred, how='left', on=['Year', 'Zipcode'])
df_complete
# Out:
#        Zipcode  RentPrice  Year  SizeRank State              City  \
# 0        02333   1368.536  2011    8782.0    MA  East Bridgewater
# 1        02338   1311.076  2011   11179.0    MA           Halifax
# 2        02339   1484.626  2011    8621.0    MA           Hanover
# 3        02341   1266.816  2011   10079.0    MA            Hanson
# 4        02343   1524.006  2011    9640.0    MA          Holbrook
# ...        ...        ...   ...       ...   ...               ...
# 264955   98279   1059.870  2018   23400.0    WA              Olga
# 264956   98280    993.850  2018   25265.0    WA         Eastsound
# 264957   98311   1533.500  2018    4981.0    WA         Bremerton
# 264958   98326    778.990  2018   26185.0    WA       Clallam Bay
# 264959   98332   1840.860  2018    6759.0    WA        Gig Harbor
#
#                           Metro       CountyName  HomePrice  Vacancy_Rate%  \
# 0       Boston-Cambridge-Newton  Plymouth County        NaN       3.024027
# 1       Boston-Cambridge-Newton  Plymouth County  274920.17       3.116343
# 2       Boston-Cambridge-Newton  Plymouth County  415097.50       4.464646
# 3       Boston-Cambridge-Newton  Plymouth County        NaN       3.586322
# 4       Boston-Cambridge-Newton   Norfolk County  247510.42       3.732901
# ...                         ...              ...        ...            ...
# 264955                      NaN  San Juan County  552805.42      51.219512
# 264956                      NaN  San Juan County  678499.00      51.329243
# 264957     Bremerton-Silverdale    Kitsap County  314320.83       6.540162
# 264958             Port Angeles   Clallam County  150193.17      28.537736
# 264959  Seattle-Tacoma-Bellevue    Pierce County  535136.75       7.340077
#
#         MOE-VacancyRate%  int_rate  med_hIncome  uspop_growth  unemplt_rate  \
# 0               2.199925  0.750000      57021.0      0.720018      8.933333
# 1               2.948791  0.750000      57021.0      0.720018      8.933333
# 2               2.066438  0.750000      57021.0      0.720018      8.933333
# 3               2.340722  0.750000      57021.0      0.720018      8.933333
# 4               2.926524  0.750000      57021.0      0.720018      8.933333
# ...                  ...       ...          ...           ...           ...
# 264955         10.993457  2.458333      64324.0      0.522337      3.891667
# 264956         12.777549  2.458333      64324.0      0.522337      3.891667
# 264957          1.960476  2.458333      64324.0      0.522337      3.891667
# 264958         14.679524  2.458333      64324.0      0.522337      3.891667
# 264959          2.726737  2.458333      64324.0      0.522337      3.891667
#
#         newHouse_starts  resConstruct_spending
# 0            611.916667          255208.583333
# 1            611.916667          255208.583333
# 2            611.916667          255208.583333
# 3            611.916667          255208.583333
# 4            611.916667          255208.583333
# ...                 ...                    ...
# 264955      1248.250000          564448.750000
# 264956      1248.250000          564448.750000
# 264957      1248.250000          564448.750000
# 264958      1248.250000          564448.750000
# 264959      1248.250000          564448.750000
#
# [264960 rows x 17 columns]

# %%
#check NaN numbers
df_complete.isna().sum()
# Out:
# Zipcode                      0
# RentPrice                19907
# Year                         0
# SizeRank                 27056
# State                    27056
# City                     27056
# Metro                    83008
# CountyName               27056
# HomePrice                37378
# Vacancy_Rate%                0
# MOE-VacancyRate%             0
# int_rate                     0
# med_hIncome                  0
# uspop_growth                 0
# unemplt_rate                 0
# newHouse_starts              0
# resConstruct_spending        0
# dtype: int64

# %%
#check NaN as a percentage
df_complete.isna().sum()/len(df_complete)*100
# Out:
# Zipcode                   0.000000
# RentPrice                 7.513210
# Year                      0.000000
# SizeRank                 10.211353
# State                    10.211353
# City                     10.211353
# Metro                    31.328502
# CountyName               10.211353
# HomePrice                14.107035
# Vacancy_Rate%             0.000000
# MOE-VacancyRate%          0.000000
# int_rate                  0.000000
# med_hIncome               0.000000
# uspop_growth              0.000000
# unemplt_rate              0.000000
# newHouse_starts           0.000000
# resConstruct_spending     0.000000
# dtype: float64

# %%
df_complete.describe()
# Out:
#            RentPrice           Year       SizeRank     HomePrice  \
# count  245053.000000  264960.000000  237904.000000  2.275820e+05
# mean     1067.691442    2014.500000   15646.706806  1.846688e+05
# std       491.626977       2.291292    9424.124602  1.858222e+05
# min        19.960000    2011.000000       0.000000  1.042183e+04
# 25%       781.625000    2012.750000    7531.000000  8.735608e+04
# 50%       942.446000    2014.500000   15164.000000  1.340185e+05
# 75%      1204.816000    2016.250000   23514.000000  2.141746e+05
# max      5620.320000    2018.000000   34430.000000  6.141946e+06
#
#        Vacancy_Rate%  MOE-VacancyRate%       int_rate    med_hIncome  \
# count  264960.000000     264960.000000  264960.000000  264960.000000
# mean       17.675088          7.996235       1.109375   60351.000000
# std        16.437987         10.221583       0.583590    2846.855913
# min         0.000000          0.000000       0.750000   56912.000000
# 25%         6.977963          2.491948       0.750000   57756.000000
# 50%        12.799977          4.855487       0.760417   59945.500000
# 75%        22.580645          9.359872       1.171875   63113.750000
# max       100.000000        100.000000       2.458333   64324.000000
#
#         uspop_growth   unemplt_rate  newHouse_starts  resConstruct_spending
# count  264960.000000  264960.000000    264960.000000          264960.000000
# mean        0.682779       6.113542      1007.885417          410836.197918
# std         0.068232       1.719867       208.944873          109740.019064
# min         0.522337       3.891667       611.916667          255208.583333
# 25%         0.672832       4.741667       892.062500          321154.395833
# 50%         0.718344       5.716667      1053.500000          410493.333333
# 75%         0.727331       7.537500      1184.291667          500871.916667
# max         0.730641       8.933333      1248.250000          564448.750000

# %% [markdown]
# ### Save Data

# %%
df_complete.to_csv(r'/Users/josephfrasca/Coding_Stuff/Springboard/Capstone_2/data/interim/master_complete_for_EDA.csv', index=False)

# %% [markdown]
# ### Notes

# %%
#need to save dataframe for 2014-2020 data (for predictions?)
#NaNs
    #find table that has state, city, metroarea, county name by zipcode to deal with thses NaNs
    #don't worry about SizeRank..??
    #rent price and home price try below... 
    #replace home price NaNs with first:
        #diff = (price of year you have) - (mean of a year you have) 
        #then with NaN do 'diff' + (mean of NaN year)

# %% [markdown]
# ### Summary
